# %%
import pandas as pd

# %%
df = pd.read_excel('PG_Romania_ALL_Data.xlsx', index_col=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1600/3233769891.py in <module>
# ----> 1 df = pd.read_excel('PG_Romania_ALL_Data.xlsx', index_col=0)
#
# C:\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\Anaconda3\lib\site-packages\pandas\io\excel\_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362     if not isinstance(io, ExcelFile):
# ...

# %%
df

# %%
df.Status.value_counts()  # df['Status'] = df.Status
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1600/2298592641.py in <module>
# ----> 1 df.Status.value_counts()  # df['Status'] = df.Status
#
# NameError: name 'df' is not defined

# %%
df['Status'].value_counts()
# Out:
# Confirmed    27249
# Rejected      1146
# Name: Status, dtype: int64

# %%
data = df[df['Status'] == 'Confirmed']

# %%
df_rj = df[~(df['Status'] == 'Confirmed')].reset_index(drop = True)

# %%
data.reset_index(drop = True, inplace = True)

# %%
data.shape()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1600/3993293784.py in <module>
# ----> 1 data.shape
#
# NameError: name 'data' is not defined

# %%
df_rj.shape
# Out:
# (1146, 11)

# %%
data.head()
# Out:
#    User_id                          ReceiptToken           CreatedAt  \
# 0     6008  0a60e3d3-12f7-471c-a191-fbeb8b4b682b 2021-03-01 15:35:18
# 1     8177  aec47af8-203d-42bc-9ef8-afd1cde9b497 2021-03-02 06:18:55
# 2     4830  70e78180-cca0-46cb-9738-ff4514b8b918 2021-03-02 08:18:20
# 3       84  bf5e1f8a-4029-48d7-b304-0d6aa20332e7 2021-03-02 10:37:48
# 4    12844  cd936864-5533-4801-b4b3-dfb39f43b6cc 2021-03-02 10:42:18
#
#      CampaignId     Status Reject Reason                           Retailer  \
# 0  pg-youtil-ro  Confirmed      datetime                          Metro LDP
# 1  pg-youtil-ro  Confirmed      datetime                              Altex
# 2  pg-youtil-ro  Confirmed      datetime                              Altex
# 3  pg-youtil-ro  Confirmed      datetime  28352783 - OPTIMUS PRIME MOLDOVEI
# 4  pg-youtil-ro  Confirmed      datetime                              Altex
#
#       Receipt DateTime Receipt Total Payment Amount  \
# ...

# %%
data = data.drop('CreatedAt', axis = 1)

# %%
data.head()
# Out:
#    User_id                          ReceiptToken    CampaignId     Status  \
# 0     6008  0a60e3d3-12f7-471c-a191-fbeb8b4b682b  pg-youtil-ro  Confirmed
# 1     8177  aec47af8-203d-42bc-9ef8-afd1cde9b497  pg-youtil-ro  Confirmed
# 2     4830  70e78180-cca0-46cb-9738-ff4514b8b918  pg-youtil-ro  Confirmed
# 3       84  bf5e1f8a-4029-48d7-b304-0d6aa20332e7  pg-youtil-ro  Confirmed
# 4    12844  cd936864-5533-4801-b4b3-dfb39f43b6cc  pg-youtil-ro  Confirmed
#
#   Reject Reason                           Retailer     Receipt DateTime  \
# 0      datetime                          Metro LDP  2021-03-01 15:10:00
# 1      datetime                              Altex  2021-03-01 00:00:00
# 2      datetime                              Altex  2021-03-02 00:00:00
# 3      datetime  28352783 - OPTIMUS PRIME MOLDOVEI  2021-03-02 12:23:00
# 4      datetime                              Altex  2021-03-02 00:00:00
#
#   Receipt Total Payment Amount  \
# 0         82.10          41.05
# ...

# %%
data.shape
# Out:
# (27249, 10)

# %%
data.nunique()
# Out:
# User_id             21075
# ReceiptToken        27248
# CampaignId              8
# Status                  1
# Reject Reason          20
# Retailer              224
# Receipt DateTime    18802
# Receipt Total       14666
# Payment Amount       3225
# Products            16692
# dtype: int64

# %%
data[data['ReceiptToken'] == '0891cf7a-5a39-4bae-a623-fe91c9171e7a']
# Out:
#        User_id                          ReceiptToken      CampaignId  \
# 20383    15028  0891cf7a-5a39-4bae-a623-fe91c9171e7a  pg-charity-2.0
# 25751    15028  0891cf7a-5a39-4bae-a623-fe91c9171e7a  pg-charity-2.0
#
#           Status Reject Reason       Retailer     Receipt DateTime  \
# 20383  Confirmed      datetime  8119423 Metro  2021-10-26 11:14:00
# 25751  Confirmed      datetime  8119423 Metro  2021-10-26 11:14:00
#
#       Receipt Total Payment Amount  \
# 20383        150.01          23.76
# 25751        150.01          26.24
#
#                                                Products
# 20383  [{"groupingId":"Ariel","total":47.52,"items":1}]
# 25751  [{"groupingId":"Ariel","total":47.52,"items":1}]

# %%
data = data.drop_duplicates(['ReceiptToken', 'CampaignId', 'Status'], keep = 'first').reset_index(drop = True)

# %%
data.nunique()
# Out:
# User_id             21075
# ReceiptToken        27248
# CampaignId              8
# Status                  1
# Reject Reason          20
# Retailer              224
# Receipt DateTime    18802
# Receipt Total       14666
# Payment Amount       3225
# Products            16692
# dtype: int64

# %%
data.shape
# Out:
# (27248, 10)

# %%
data.head()
# Out:
#    User_id                          ReceiptToken    CampaignId     Status  \
# 0     6008  0a60e3d3-12f7-471c-a191-fbeb8b4b682b  pg-youtil-ro  Confirmed
# 1     8177  aec47af8-203d-42bc-9ef8-afd1cde9b497  pg-youtil-ro  Confirmed
# 2     4830  70e78180-cca0-46cb-9738-ff4514b8b918  pg-youtil-ro  Confirmed
# 3       84  bf5e1f8a-4029-48d7-b304-0d6aa20332e7  pg-youtil-ro  Confirmed
# 4    12844  cd936864-5533-4801-b4b3-dfb39f43b6cc  pg-youtil-ro  Confirmed
#
#   Reject Reason                           Retailer     Receipt DateTime  \
# 0      datetime                          Metro LDP  2021-03-01 15:10:00
# 1      datetime                              Altex  2021-03-01 00:00:00
# 2      datetime                              Altex  2021-03-02 00:00:00
# 3      datetime  28352783 - OPTIMUS PRIME MOLDOVEI  2021-03-02 12:23:00
# 4      datetime                              Altex  2021-03-02 00:00:00
#
#   Receipt Total Payment Amount  \
# 0         82.10          41.05
# ...

# %%
data.sort_values(by = 'User_id', ascending = False)
# Out:
#        User_id                          ReceiptToken         CampaignId  \
# 21572    21692  161e3482-3376-4c48-b0b1-03030136f514     pg-charity-2.0
# 16244    21691  0fc34bea-008c-4695-97f8-0c4ca0fe2070      pg-charity-ro
# 3362     21690  48d4a5b9-6a1f-4b83-aee9-b1a4066e4f97       pg-youtil-ro
# 20304    21690  720428f6-a797-4ab5-a7f3-f1443ab88aa4     pg-charity-2.0
# 16725    21689  44211ea1-8ad5-45e7-a976-b35be56b344c  pampers-auchan-ro
# ...        ...                                   ...                ...
# 20336        3  a01e70c1-fd67-4604-8e0d-e557ce1e5bad     pg-charity-2.0
# 18679        3  1bfebbac-d011-4225-9fc8-ca27c8acaaa3           pg-30-ro
# 15813        2  609af952-0753-4555-93a7-17ede167faf9      pg-charity-ro
# 8799         1  a35c7fd3-43c7-406d-9996-eacec8c775c8       pg-youtil-ro
# 6743         0  5be9a490-de0d-4cbd-ab29-6f053fcaf1c5       pg-youtil-ro
#
#           Status Reject Reason                       Retailer  \
# ...

# %%
data
# Out:
#        User_id                          ReceiptToken    CampaignId     Status  \
# 0         6008  0a60e3d3-12f7-471c-a191-fbeb8b4b682b  pg-youtil-ro  Confirmed
# 1         8177  aec47af8-203d-42bc-9ef8-afd1cde9b497  pg-youtil-ro  Confirmed
# 2         4830  70e78180-cca0-46cb-9738-ff4514b8b918  pg-youtil-ro  Confirmed
# 3           84  bf5e1f8a-4029-48d7-b304-0d6aa20332e7  pg-youtil-ro  Confirmed
# 4        12844  cd936864-5533-4801-b4b3-dfb39f43b6cc  pg-youtil-ro  Confirmed
# ...        ...                                   ...           ...        ...
# 27243    10582  71011b57-7cb2-4f8c-b12e-e3db9aa190c2  lenor-un-2.0  Confirmed
# 27244    17582  e33b48fc-6c50-4c70-af97-a800b3b40ae6  lenor-un-2.0  Confirmed
# 27245    21484  c769bb6e-efaf-463f-a3dc-f9877075a0a6  lenor-un-2.0  Confirmed
# 27246    14487  fec48aa6-48a1-4c87-ad3c-ec7bc170fd5c  lenor-un-2.0  Confirmed
# 27247    11011  6a29f32a-f703-428e-adb7-ee21b2c1881c  lenor-un-2.0  Confirmed
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27248 entries, 0 to 27247
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_id           27248 non-null  int64
#  1   ReceiptToken      27248 non-null  object
#  2   CampaignId        27248 non-null  object
#  3   Status            27248 non-null  object
#  4   Reject Reason     27248 non-null  object
#  5   Retailer          27248 non-null  object
#  6   Receipt DateTime  27248 non-null  object
#  7   Receipt Total     27248 non-null  object
#  8   Payment Amount    27248 non-null  object
#  9   Products          27248 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.1+ MB

# %%
pd.to_numeric(data['Receipt Total'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-6c96fcc19adc> in <module>
# ----> 1 pd.to_numeric(data['Receipt Total'])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     151         try:
#     152             values = lib.maybe_convert_numeric(
# --> 153                 values, set(), coerce_numeric=coerce_numeric
#     154             )
#     155         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type at position 1913

# %%
data.loc[1913]
# Out:
# User_id                                                         12563
# ReceiptToken                     eab3d064-06bb-46e8-b6ee-97c39d42c0fd
# CampaignId                                               pg-youtil-ro
# Status                                                      Confirmed
# Reject Reason                                                datetime
# Retailer                                                         eMag
# Receipt DateTime                                  2021-03-11 00:00:00
# Receipt Total                                     2022-09-17 00:00:00
# Payment Amount                                                   8.54
# Products            [{"groupingId":"Gillette","total":17.09,"items...
# Name: 1913, dtype: object

# %%
data['Reject Reason'] = data['Reject Reason'].str.replace('datetime', 'Datetime')

# %%
data
# Out:
#        User_id                          ReceiptToken    CampaignId     Status  \
# 0         6008  0a60e3d3-12f7-471c-a191-fbeb8b4b682b  pg-youtil-ro  Confirmed
# 1         8177  aec47af8-203d-42bc-9ef8-afd1cde9b497  pg-youtil-ro  Confirmed
# 2         4830  70e78180-cca0-46cb-9738-ff4514b8b918  pg-youtil-ro  Confirmed
# 3           84  bf5e1f8a-4029-48d7-b304-0d6aa20332e7  pg-youtil-ro  Confirmed
# 4        12844  cd936864-5533-4801-b4b3-dfb39f43b6cc  pg-youtil-ro  Confirmed
# ...        ...                                   ...           ...        ...
# 27243    10582  71011b57-7cb2-4f8c-b12e-e3db9aa190c2  lenor-un-2.0  Confirmed
# 27244    17582  e33b48fc-6c50-4c70-af97-a800b3b40ae6  lenor-un-2.0  Confirmed
# 27245    21484  c769bb6e-efaf-463f-a3dc-f9877075a0a6  lenor-un-2.0  Confirmed
# 27246    14487  fec48aa6-48a1-4c87-ad3c-ec7bc170fd5c  lenor-un-2.0  Confirmed
# 27247    11011  6a29f32a-f703-428e-adb7-ee21b2c1881c  lenor-un-2.0  Confirmed
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27248 entries, 0 to 27247
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_id           27248 non-null  int64
#  1   ReceiptToken      27248 non-null  object
#  2   CampaignId        27248 non-null  object
#  3   Status            27248 non-null  object
#  4   Reject Reason     27248 non-null  object
#  5   Retailer          27248 non-null  object
#  6   Receipt DateTime  27248 non-null  object
#  7   Receipt Total     27248 non-null  object
#  8   Payment Amount    27248 non-null  object
#  9   Products          27248 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.1+ MB

# %%
data = data.drop(data[data['Receipt Total'].apply(str).str.contains('202.-')].index).reset_index(drop = True)

# %%
data['Receipt Total'] = pd.to_numeric(data['Receipt Total'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27200 entries, 0 to 27199
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_id           27200 non-null  int64
#  1   ReceiptToken      27200 non-null  object
#  2   CampaignId        27200 non-null  object
#  3   Status            27200 non-null  object
#  4   Reject Reason     27200 non-null  object
#  5   Retailer          27200 non-null  object
#  6   Receipt DateTime  27200 non-null  object
#  7   Receipt Total     27200 non-null  float64
#  8   Payment Amount    27200 non-null  object
#  9   Products          27200 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 2.1+ MB

# %%
data.sort_values('Receipt Total', ascending = False)
# Out:
#        User_id                          ReceiptToken      CampaignId  \
# 18438    12884  0c7b55a4-adbb-4223-abdd-3983b6b68eb8        pg-30-ro
# 6544      3785  ad302b6b-2743-4e55-a190-be8d251f3d97    pg-youtil-ro
# 3677     10491  c54c8265-8f53-4875-be67-9b1e798149bc    pg-youtil-ro
# 1269     12370  b168d44f-c688-4ec0-8faf-f242d9c2ee5b    pg-youtil-ro
# 5182      8188  f7016ead-11d5-4041-8f0b-c65a7e838177    pg-youtil-ro
# ...        ...                                   ...             ...
# 22088     1527  2ade3eb6-162a-43c0-88bc-fe9220622659  pg-charity-2.0
# 5835     18042  58ff9ae9-483f-49c2-92cd-26f493f24dec    pg-youtil-ro
# 20845    12213  6ed1b8a4-ea64-4319-8e4b-0daad0ee1842  pg-charity-2.0
# 6766      9746  9f9d75db-6802-4072-af65-be36e67f02ef    pg-youtil-ro
# 14215     3728  bec3dc56-d4c3-4a79-92c7-6db85f0547f7    pg-youtil-ro
#
#           Status Reject Reason           Retailer     Receipt DateTime  \
# ...
